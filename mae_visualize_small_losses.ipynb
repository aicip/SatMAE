# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # MAE Model Visualization

# %%
import viz

# %% [markdown]
# ## Load pre-trained MAE model

# %%
common_architecture = "mae_vit_small"

model_mse = viz.prepare_model(
    chkpt_dir=f"out_{common_architecture}_xformers_scaled_dot_product_MLP_i64_p8_b256_e200_mse_lr0.0005",
    arch=common_architecture
)

model_l1 = viz.prepare_model(
    chkpt_dir=f"out_{common_architecture}_xformers_scaled_dot_product_MLP_i64_p8_b256_e200_l1_lr0.0005",
    chkpt_name="100",
    arch=common_architecture
)

models = {"SDP - MSE": model_mse, "SDP - L1": model_l1}
# Out:
# ================================================================================
# Loading checkpoint:  ../Model_Saving/out_mae_vit_small_xformers_scaled_dot_product_MLP_i64_p8_b256_e200_mse_lr0.0005/checkpoint-199.pth
# args: {'batch_size': 256, 'epochs': 200, 'accum_iter': 1, 'model_type': None, 'model': 'mae_vit_small', 'input_size': 64, 'patch_size': '8', 'attn_name': 'scaled_dot_product', 'print_level': 1, 'mask_ratio': 0.75, 'ffn_name': 'MLP', 'use_xformers': True, 'spatial_mask': False, 'loss': 'mse', 'norm_pix_loss': False, 'weight_decay': 0.05, 'lr': 0.001, 'blr': 0.001, 'min_lr': 0.0, 'warmup_epochs': 40, 'train_path': '../fmow-rgb-preproc/train_64.csv', 'dataset_type': 'rgb', 'masked_bands': None, 'dropped_bands': None, 'grouped_bands': [], 'output_dir': '../Model_Saving/out_mae_vit_small_xformers_scaled_dot_product_MLP_i64_p8_b256_e200_mse_lr0.0005', 'log_dir': './logs', 'device': 'cuda', 'seed': 0, 'resume': '', 'wandb': 'satmae', 'wandb_entity': 'utk-iccv23', 'start_epoch': 0, 'num_workers': 10, 'pin_mem': True, 'world_size': 1, 'local_rank': 0, 'dist_on_itp': False, 'dist_url': 'env://', 'distributed': False}
# Using xformers
# <All keys matched successfully>
# Model loaded.
# ================================================================================
# Loading checkpoint:  ../Model_Saving/out_mae_vit_small_xformers_scaled_dot_product_MLP_i64_p8_b256_e200_l1_lr0.0005/checkpoint-100.pth
# args: {'batch_size': 256, 'epochs': 200, 'accum_iter': 1, 'model_type': None, 'model': 'mae_vit_small', 'input_size': 64, 'patch_size': '8', 'attn_name': 'scaled_dot_product', 'print_level': 1, 'mask_ratio': 0.75, 'ffn_name': 'MLP', 'use_xformers': True, 'spatial_mask': False, 'loss': 'l1', 'norm_pix_loss': False, 'weight_decay': 0.05, 'lr': 0.001, 'blr': 0.001, 'min_lr': 0.0, 'warmup_epochs': 40, 'train_path': '../fmow-rgb-preproc/train_64.csv', 'dataset_type': 'rgb', 'masked_bands': None, 'dropped_bands': None, 'grouped_bands': [], 'output_dir': '../Model_Saving/out_mae_vit_small_xformers_scaled_dot_product_MLP_i64_p8_b256_e200_l1_lr0.0005', 'log_dir': './logs', 'device': 'cuda', 'seed': 0, 'resume': '', 'wandb': 'satmae', 'wandb_entity': 'utk-iccv23', 'start_epoch': 0, 'num_workers': 10, 'pin_mem': True, 'world_size': 1, 'local_rank': 0, 'dist_on_itp': False, 'dist_url': 'env://', 'distributed': False}
# Using xformers
# <All keys matched successfully>
# Model loaded.

# %% [markdown]
# ## Run on selected images from './images' folder

# %%
viz.plot_comp_many(
    models,
    "./images",
    maskseed=1234,
    base_title=f"{common_architecture} - Comparing Losses",
    save=True,
)

# %% [markdown]
# ## Run on random images from the test set

# %%
viz.plot_comp_many(
    models,
    "../fmow-rgb-preproc/data_64/input/test_data/test/",
    max_img_samples=20,
    random_walk=True,
    walkseed=123,
    maskseed=None,
    base_title=f"{common_architecture} - Comparing Losses",
    save=False,
)
